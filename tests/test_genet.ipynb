# %%
import os 

sBase_DIR =  os.getcwd()
best_model_path = '%s/models/DeepSpCas9' % sBase_DIR
best_model_path
# Out:
# 'd:\\github_project\\genet\\tests/models/DeepSpCas9'

# %%
path = os.path.realpath(__file__)
directory = os.path.dirname(path)

directory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\github_project\genet\tests\test_genet.ipynb 셀 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/github_project/genet/tests/test_genet.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> path = os.path.realpath(__file__)
#       <a href='vscode-notebook-cell:/d%3A/github_project/genet/tests/test_genet.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> directory = os.path.dirname(path)
#       <a href='vscode-notebook-cell:/d%3A/github_project/genet/tests/test_genet.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> directory
#
# NameError: name '__file__' is not defined

# %%
gpu_env = 1
test  = '%d' % gpu_env
test
# Out:
# '1'

# %%
from genet.predict import pe_score

score = pe_score('aa', 'aa', 'sub1')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# e:\github_project\genet\tests\test_genet.ipynb 셀 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/github_project/genet/tests/test_genet.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from genet.predict import pe_score
#       <a href='vscode-notebook-cell:/e%3A/github_project/genet/tests/test_genet.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> score = pe_score('aa', 'aa', 'sub1')
#
# ModuleNotFoundError: No module named 'genet'
